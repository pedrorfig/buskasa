# %%
import requests

# %%
import requests

cookies = {
    'X-AB-Test': 'ab_alert_iterations:0,ab_alerts_whatsapp:0,ab_condos_rebrand:-1,ab_hls_client_list:-1,ab_hls_rollout_clusters_list:0,ab_hls_ssr_list:-1,ab_listing_reports:-1,ab_listing_weather_v2:1,ab_ltr_sale_ranking_experiment_fix:0,ab_map_draw_area_v2:1,ab_rede_boosting_v2:1,ab_remove_document_number:0,ab_street_search_highlight_v1:0',
    '5ANNEX': 'eyJ1dWlkIjoiMXRYR3l3V01JUkZPS21FVFp4dHJncElfaU9jS1NmTUtzckU2Z0dyLU9pUGwyWlFOeU1XcWlRIn0',
    '_hjFirstSeen': '1',
    '_hjSession_1203740': 'eyJpZCI6IjVmNDhlY2Q4LWU5NjAtNGFlMS1iZGNiLTQwMjVmZGZiZTM5NSIsImNyZWF0ZWQiOjE2OTU1MDg1ODEyNzgsImluU2FtcGxlIjpmYWxzZX0=',
    '_gcl_au': '1.1.992941299.1695508581',
    '_hjSessionUser_1203740': 'eyJpZCI6IjZmYjZiODRiLTQwYWEtNTc2Mi05NWRhLWEzN2JkY2E3M2Q2ZSIsImNyZWF0ZWQiOjE2OTU1MDg1ODEyNzcsImV4aXN0aW5nIjp0cnVlfQ==',
    '5AJWT_AUTH': 'eyJhbGciOiJSUzI1NiJ9.....XSdXkwS7JaTaHMJ0Y3oYxj_IqqsylNmLjgLx_EhINrKZi_5WBhoYuHERa_d8AeSqlc1qzVgrPFOdmyB6xD7EP_rpr6nERXbaBPJ4GuvHyIpg6Eyi5qd9JPpNtq0uHVuIN0Oh65nn4LAgg4_JjNp7OlB4VK88qHmQ_NgiJlDqHwu9NlmnMM_FOCwf00TU5Og5UqysILG9qiQVtj8ZNQAHbj3RN1K-0KJ86K_89cmRE6unvfMSe0M9QKn6ccecoRcsFx6xtNt_7em_j_yx0leiCT71lwUAsS28WMqvtOqRknUsWx04aAVqieJIRtqY4WJtA01IFftSlh1VuGvJ-p5YXw',
    'ab_alerts_whatsapp': '1',
    '5A_COOKIE_ACCEPT': '%7B%22categories%22%3A%5B%22necessary%22%2C%22performance%22%2C%22targeting%22%2C%22functional%22%5D%7D',
    '_uetsid': 'a0f1cb205a6111eea7d2bdbceae2d9ce',
    '_uetvid': 'a0f248105a6111ee985f9d5d9833c691',
    'ab.storage.sessionId.cf9e8c77-7b32-4126-940b-b58658d0918e': '%7B%22g%22%3A%224a6eff3d-328e-786e-fa57-47057290db22%22%2C%22e%22%3A1695512985607%2C%22c%22%3A1695511105986%2C%22l%22%3A1695511185607%7D',
    'cto_bundle': '',
    'amplitude_id_3fbf25d58c3cce92f0e6609904a37cc9quintoandar.com.br': '',
}

headers = {
    'authority': 'www.quintoandar.com.br',
    'accept': 'application/p_click_version.V3.4+p_click_sale_version.V1+json',
    'accept-language': 'en-US,en;q=0.9,pt-BR;q=0.8,pt;q=0.7',
    'content-type': 'text/plain;charset=UTF-8',
    # 'cookie': 'X-AB-Test=ab_alert_iterations:0,ab_alerts_whatsapp:0,ab_condos_rebrand:-1,ab_hls_client_list:-1,ab_hls_rollout_clusters_list:0,ab_hls_ssr_list:-1,ab_listing_reports:-1,ab_listing_weather_v2:1,ab_ltr_sale_ranking_experiment_fix:0,ab_map_draw_area_v2:1,ab_rede_boosting_v2:1,ab_remove_document_number:0,ab_street_search_highlight_v1:0; 5ANNEX=eyJ1dWlkIjoiMXRYR3l3V01JUkZPS21FVFp4dHJncElfaU9jS1NmTUtzckU2Z0dyLU9pUGwyWlFOeU1XcWlRIn0; _hjFirstSeen=1; _hjSession_1203740=eyJpZCI6IjVmNDhlY2Q4LWU5NjAtNGFlMS1iZGNiLTQwMjVmZGZiZTM5NSIsImNyZWF0ZWQiOjE2OTU1MDg1ODEyNzgsImluU2FtcGxlIjpmYWxzZX0=; _gcl_au=1.1.992941299.1695508581; _hjSessionUser_1203740=eyJpZCI6IjZmYjZiODRiLTQwYWEtNTc2Mi05NWRhLWEzN2JkY2E3M2Q2ZSIsImNyZWF0ZWQiOjE2OTU1MDg1ODEyNzcsImV4aXN0aW5nIjp0cnVlfQ==; 5AJWT_AUTH=eyJhbGciOiJSUzI1NiJ9.....XSdXkwS7JaTaHMJ0Y3oYxj_IqqsylNmLjgLx_EhINrKZi_5WBhoYuHERa_d8AeSqlc1qzVgrPFOdmyB6xD7EP_rpr6nERXbaBPJ4GuvHyIpg6Eyi5qd9JPpNtq0uHVuIN0Oh65nn4LAgg4_JjNp7OlB4VK88qHmQ_NgiJlDqHwu9NlmnMM_FOCwf00TU5Og5UqysILG9qiQVtj8ZNQAHbj3RN1K-0KJ86K_89cmRE6unvfMSe0M9QKn6ccecoRcsFx6xtNt_7em_j_yx0leiCT71lwUAsS28WMqvtOqRknUsWx04aAVqieJIRtqY4WJtA01IFftSlh1VuGvJ-p5YXw; ab_alerts_whatsapp=1; 5A_COOKIE_ACCEPT=%7B%22categories%22%3A%5B%22necessary%22%2C%22performance%22%2C%22targeting%22%2C%22functional%22%5D%7D; _uetsid=a0f1cb205a6111eea7d2bdbceae2d9ce; _uetvid=a0f248105a6111ee985f9d5d9833c691; ab.storage.sessionId.cf9e8c77-7b32-4126-940b-b58658d0918e=%7B%22g%22%3A%224a6eff3d-328e-786e-fa57-47057290db22%22%2C%22e%22%3A1695512985607%2C%22c%22%3A1695511105986%2C%22l%22%3A1695511185607%7D; cto_bundle=; amplitude_id_3fbf25d58c3cce92f0e6609904a37cc9quintoandar.com.br=',
    'dnt': '1',
    'origin': 'https://www.quintoandar.com.br',
    'sec-ch-ua': '"Google Chrome";v="117", "Not;A=Brand";v="8", "Chromium";v="117"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36',
    'x-device-id': '1tXGywWMIRFOKmETZxtrgpI_iOcKSfMKsrE6gGr-OiPl2ZQNyMWqiQ',
    'x-instana-l': '1,correlationType=web;correlationId=54d5f502672c411c',
    'x-instana-s': '54d5f502672c411c',
    'x-instana-t': '54d5f502672c411c',
    'x-user-id': '451328',
}

params = {
    'photos': '12',
    'relax_query': 'false',
}

data = '{"filters":{"map":{"bounds_north":-23.547272828564747,"bounds_south":-23.57988314773635,"bounds_east":-46.681993962890616,"bounds_west":-46.701220037109366,"center_lat":-23.56357798815055,"center_lng":-46.69160699999999},"cost":{"cost_type":"sale_price","max_value":1200000,"min_value":150000},"min_bedrooms":3,"availability":"any","occupancy":"any","house_type":["Apartamento"],"country_code":"BR","keyword_match":["neighborhood:Pinheiros"],"sorting":{"criteria":"relevance_sale","order":"desc"},"page_size":11,"offset":0,"search_dropdown_value":"Pinheiros, São Paulo - SP, Brasil"},"return":["id","coverImage","rent","totalCost","salePrice","iptuPlusCondominium","area","imageList","imageCaptionList","address","regionName","city","visitStatus","activeSpecialConditions","type","forRent","forSale","isPrimaryMarket","bedrooms","parkingSpaces","listingTags","yield","yieldStrategy","neighbourhood","categories","bathrooms","isFurnished","installations"],"business_context":"SALE","user_id":451328,"device_id":"1tXGywWMIRFOKmETZxtrgpI_iOcKSfMKsrE6gGr-OiPl2ZQNyMWqiQ","relax_query":false,"force_raw_search":false,"search_query_context":"neighborhood"}'.encode()

response = requests.post(
    'https://www.quintoandar.com.br/api/yellow-pages/v2/search',
    params=params,
    cookies=cookies,
    headers=headers,
    data=data,
)

# %%
response.json().get('hits')
# Out:
# {'total': {'value': 112, 'relation': 'eq'},
#  'max_score': 1.0,
#  'hits': [{'_id': '894041015',
#    '_score': 1.0,
#    '_source': {'id': 894041015,
#     'coverImage': '894041015-223.67820131185986422a4fd-02a7-4ca5-b17f-cc8b12519a59-LEAD3P-98eadece-597f-4b99-b2c5-371bb8ae3d67.JPG',
#     'rent': 0,
#     'totalCost': 1666,
#     'salePrice': 1048000,
#     'iptuPlusCondominium': 1666,
#     'area': 95,
#     'imageList': ['894041015-223.67820131185986422a4fd-02a7-4ca5-b17f-cc8b12519a59-LEAD3P-98eadece-597f-4b99-b2c5-371bb8ae3d67.JPG',
#      '894041015-82.692721085975256422a4fd-02a7-4ca5-b17f-cc8b12519a59-LEAD3P-6d10e5d0-636e-45ae-bb75-f099b1118b5a.JPG',
#      '894041015-998.11313735107856422a4fd-02a7-4ca5-b17f-cc8b12519a59-LEAD3P-67e1e00b-a59f-40ed-a7b2-a61af3693c11.JPG',
#      '894041015-895.24829962443756422a4fd-02a7-4ca5-b17f-cc8b12519a59-LEAD3P-ef02f533-009c-489b-8520-c079a04e163b.JPG',
# ...

# %%
listings = response.json().get('hits').get('hits')
listings
# Out:
# [{'_id': '894041015',
#   '_score': 1.0,
#   '_source': {'id': 894041015,
#    'coverImage': '894041015-223.67820131185986422a4fd-02a7-4ca5-b17f-cc8b12519a59-LEAD3P-98eadece-597f-4b99-b2c5-371bb8ae3d67.JPG',
#    'rent': 0,
#    'totalCost': 1666,
#    'salePrice': 1048000,
#    'iptuPlusCondominium': 1666,
#    'area': 95,
#    'imageList': ['894041015-223.67820131185986422a4fd-02a7-4ca5-b17f-cc8b12519a59-LEAD3P-98eadece-597f-4b99-b2c5-371bb8ae3d67.JPG',
#     '894041015-82.692721085975256422a4fd-02a7-4ca5-b17f-cc8b12519a59-LEAD3P-6d10e5d0-636e-45ae-bb75-f099b1118b5a.JPG',
#     '894041015-998.11313735107856422a4fd-02a7-4ca5-b17f-cc8b12519a59-LEAD3P-67e1e00b-a59f-40ed-a7b2-a61af3693c11.JPG',
#     '894041015-895.24829962443756422a4fd-02a7-4ca5-b17f-cc8b12519a59-LEAD3P-ef02f533-009c-489b-8520-c079a04e163b.JPG',
#     '894041015-537.53663472477686422a4fd-02a7-4ca5-b17f-cc8b12519a59-LEAD3P-0aaad90c-baf3-4578-8691-09f2980b269a.JPG',
# ...

# %%
first_listing = listings[3]
price = first_listing['_source']['salePrice']
area = first_listing['_source']['area']
condo_fee = first_listing['_source']['iptuPlusCondominium']
city = first_listing['_source']['city']
neighborhood = first_listing['_source']['regionName']
street = first_listing['_source']['address']
first_listing
# Out:
# {'_id': '893881050',
#  '_score': 1.0,
#  '_source': {'id': 893881050,
#   'coverImage': '893881050-107.6412817958775IMG0808jpg.jpg',
#   'rent': 3200,
#   'totalCost': 4542,
#   'salePrice': 800000,
#   'iptuPlusCondominium': 1231,
#   'area': 90,
#   'imageList': ['893881050-107.6412817958775IMG0808jpg.jpg',
#    '893881050-916.7215210438718IMG0809jpg.jpg',
#    '893881050-459.44716798702933IMG0810jpg.jpg',
#    '893881050-951.6958174499922IMG0811jpg.jpg',
#    '893881050-380.77612198053714IMG0812jpg.jpg',
#    '893881050-733.4712894945516IMG0813jpg.jpg',
#    '893881050-59.77612200149418IMG0814jpg.jpg',
#    '893881050-748.071540293832IMG0815jpg.jpg',
#    '893881050-179.99046058645087IMG0816jpg.jpg',
#    '893881050-634.2294066773146IMG0817jpg.jpg',
#    '893881050-271.4957045895707IMG0818jpg.jpg',
#    '893881050-595.0852009325372IMG0819jpg.jpg'],
#   'imageCaptionList': ['Sala',
#    'Sala',
#    'Sala',
#    'Sala',
#    'Sala',
#    'Corredor',
#    'Quarto 1',
# ...
